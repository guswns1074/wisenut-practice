# %%
import pytesseract
import cv2

def ocr(image):
    img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    img_gray = cv2.bitwise_not(cv2.adaptiveThreshold(img_gray, 255, cv2.THRESH_BINARY, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 75, 10))
    pytesseract.image_to_string(img_gray, lang="kor")

# %%
import urllib.request
import numpy as np
import cv2

def url_to_image(url):
    url = urllib.parse.quote(url)
    resp = urllib.request.urlopen(url)
    image = np.asarray(bytearray(resp.read()), dtype="uint8")
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
    return image

# %%
image2 = url_to_image('https://postfiles.pstatic.net/MjAxOTA5MDJfMTU0/MDAxNTY3NDEzODU3MjMy.y9gzURzvTs4JyNrL1dySKEVC6IVnWXCx12CN_hI_ndsg.B5XSoAxEZgqAG-UW656AovbsknBNclz-c_DdkVjsgAsg.JPEG.gmdshop/Screenshot_2019-09-02_at_17.44.01.jpg?type=w966')

# %%
img = cv2.imread('5.jpg')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray = cv2.bitwise_not(cv2.adaptiveThreshold(img_gray, 255, cv2.THRESH_BINARY, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 75, 10))
pytesseract.image_to_string(img_gray, lang="kor")
# Out:
# ''

# %%
cv2.imshow("w",img_gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import re
import requests

browser="C:\\Users\CPB06GameN\Anaconda3\envs\chromedriver.exe"
driver=webdriver.Chrome(browser)

url = 'https://blog.naver.com/daily__y/221640619251'
url2 = 'https://blog.naver.com/gmdshop/221636476527'

driver.get(url2)
driver.switch_to.frame('mainFrame')
html = driver.page_source

# req = requests.get(url)
# html = req.text
soup = BeautifulSoup(html,'html.parser')
# mainFrame = soup.find('iframe',{'id':'mainFrame'})['src']
driver.
soup.find('title').text

# %%
soup.head.find('meta',{'property':'og:title'})['content']
# Out:
# '집안청소 다이슨V11 무선청소기 구석구석 깨끗하게!'

# %%
soup.head.find('meta',{'property':'og:description'})['content']
# Out:
# '낮에는 기온이 엄청 뜨끈하지만처서가 지나고 나니 가을이 된다는 느낌을 확 받고 있는데요.그건 제 피부 ...'

# %%
soup.find('description')

# %%
html
# Out:
# '<html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"><head><script async="" src="https://sstatic-g.rmcnmv.naver.net/resources/js/naver_web_player_all_common_min.js"></script><script async="" src="https://sstatic-g.rmcnmv.naver.net/resources/js/naver_web_player_all_common_min.js"></script>\n<meta http-equiv="Pragma" content="no-cache">\n<meta http-equiv="Expires" content="-1">\n\n<meta name="referrer" content="always">\n\n\n\n\n\n\n\n\n<!--[if ie]>\n<style type="text/css">\nhtml {overflow: scroll; overflow-x: auto;}\n</style>\n<![endif]-->\n\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/t.static.blog/mylog/versioning/LayoutTopCommon-587782767_https.css" charset="UTF-8">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/t.static.blog/mylog/versioning//common/css/music/player-d3fc09e_https.css">\n\n<link rel="shortcut icon" type="image/x-icon" href=
# ...

# %%
soup.find_all('div',{'class : se-text-paragraph se-text-paragraph-align-center'})
# Out:
# []

# %%
soup.find('div',{'class' : 'se-module se-module-text'}).find_all('p',{'class':'se-text-paragraph se-text-paragraph-align-center'})[0].text
# Out:
# '낮에는 기온이 엄청 뜨끈하지만'

# %%
text_list = soup.find_all('div',{'class' : 'se-module se-module-text'})
date = soup.find('span',{'class': 'se_publishDate pcol2'}).text
title = soup.find('div',{'class': 'se-module se-module-text se-title-text'}).text.replace('\n','')
<div class="se-section se-section-image se-l-default se-section-align-center">

                                <a href="#" class="se-module se-module-image __se_image_link __se_link" style=" " onclick="return false;" data-linktype="img" data-linkdata="{&quot;id&quot; : &quot;SE-edd09c63-e099-460a-8477-83e122e82e54&quot;, &quot;src&quot; : &quot;https://postfiles.pstatic.net/MjAxOTA4MjZfNjUg/MDAxNTY2Nzk4MjkxNjgx.fa7tUzSAwLWxcifNneQr5O04eSKWauLuIzBCjEVPKmIg.A78ZW4PmmRaiA72B8RxVzzPvZizJ1kjVBagWN7EBT3kg.PNG.gmdshop/다이슨_AS_이미지.png&quot;, &quot;linkUse&quot; : &quot;false&quot;, &quot;link&quot; : &quot;&quot;}">
                                    <img src="https://postfiles.pstatic.net/MjAxOTA4MjZfNjUg/MDAxNTY2Nzk4MjkxNjgx.fa7tUzSAwLWxcifNneQr5O04eSKWauLuIzBCjEVPKmIg.A78ZW4PmmRaiA72B8RxVzzPvZizJ1kjVBagWN7EBT3kg.PNG.gmdshop/다이슨_AS_이미지.png?type=w966" data-lazy-src="" data-width="886" data-height="215" alt="" class="se-image-resource">
                                </a>                        </div>

# %%
title
# Out:
# '집안청소 다이슨V11 무선청소기 구석구석 깨끗하게! '

# %%
soup.find_all('div',{'class': 'se-component se-image se-l-default'})[-1]
# Out:
# <div class="se-component se-image se-l-default" id="SE-dd4db167-4d36-4361-8c07-cd1acb32257b">
# <div class="se-component-content se-component-content-normal">
# <div class="se-section se-section-image se-l-default se-section-align-center" style="max-width:526px;">
# <a class="se-module se-module-image __se_image_link __se_link" data-linkdata='{"id" : "SE-dd4db167-4d36-4361-8c07-cd1acb32257b", "src" : "https://postfiles.pstatic.net/MjAxOTA5MDJfMTU0/MDAxNTY3NDEzODU3MjMy.y9gzURzvTs4JyNrL1dySKEVC6IVnWXCx12CN_hI_ndsg.B5XSoAxEZgqAG-UW656AovbsknBNclz-c_DdkVjsgAsg.JPEG.gmdshop/Screenshot_2019-09-02_at_17.44.01.jpg", "linkUse" : "false", "link" : ""}' data-linktype="img" href="#" onclick="return false;" style=" ">
# ...

# %%
soup.find_all('div',{'class': 'se-component se-image se-l-default'})[-1].find('img')['src']
# Out:
# 'https://postfiles.pstatic.net/MjAxOTA5MDJfMTU0/MDAxNTY3NDEzODU3MjMy.y9gzURzvTs4JyNrL1dySKEVC6IVnWXCx12CN_hI_ndsg.B5XSoAxEZgqAG-UW656AovbsknBNclz-c_DdkVjsgAsg.JPEG.gmdshop/Screenshot_2019-09-02_at_17.44.01.jpg?type=w966'

# %%
text_list = soup.find_all('div',{'class' : 'se-module se-module-text'})
fin = ''
for i in text_list:
    txt = i.find_all('p',{'class':'se-text-paragraph se-text-paragraph-align-center'})
    for j in txt:
        fin = fin + j.text + ' '
fin = fin.replace('\u200b','')
# Out:
# '낮에는 기온이 엄청 뜨끈하지만처서가 지나고 나니 가을이 된다는 느낌을 확 받고 있는데요.그건 제 피부 만이 아니라 알프도 그런가 보더라고요.슬슬 또 털이 빠지기 시작했어요.지금 한참 솜털을 벗고 다시 새 털로 빵실하게 쪄야추운 겨울 잘 날 수 있을테니,저는 이제부터 집안청소 비상입니다.하지만 이제 큰 걱정하지 않고 있어요.왜냐하면 저의 주변 환경을 깨끗하게 만들어주는효자템은 바로 다이슨V11 무선청소기가 있기 때문이라죠.다양한 툴을 교체하여 마루바닥, 카페트, 좁은 틈새, 가구, 가전, 침구, 매트리스, 소파까지다재다능하게 사용하고 있거든요.청소를 해야겠다는 마음과 시간과 노동력만 준비되면집안은 언제든지 깨끗하게 반짝 반짝 빛날 수 있답니다.올 4월부터 사용을 시작했으니 벌서 5개월 차에 접어 들었는데요.그동안 사용하면서 느꼈던 점들 솔직 담백하게 담아볼게요.집안 분위기도 좀 바꿀 겸 여름이라 시원한 느낌도 줄 겸새로운 컬러감의 카페트를 마루에 깔아두었어요.12살 알프 관절이 걱정되다보니 항상 카페트를 깔아두고 미끄러지 지지 않게 관리하는데요.이전에 사용하던 카페트는 무난무난하고 그냥 점잖은 연한 그레이 컬러 였거든요.깔끔한 느낌인 대신에 하얀 알프털도 안보여서 편하게 살았는데요.이번에는 컬러감이 있는 제품이다보니 털갈이 시작되는 것을 바로 알려주더라고요.한번씩 몸을 부르르 털고가면 저렇게 잔재들이 떨어져요.지금은 초반이라 저 정도지 시간 지나면 아마 수북하겠죠?근데 댕댕이 기르시는 분들은 아실텐데차라리 많이 빠지는 털이 청소가 더 쉽거든요.저렇게 한 두개씩 빠지면 카페트 같은데는 섬유 속에 파고 들어서흡입력 좋은 무선청소기 사용하거나 아니면 일일이 손으로 제거해줘야할 때도 있답니다.뭐 저는 그래도 걱정 없죠.흡입력 하면 알아주는 다이슨V11 자동모드로 청소해주면 되니까요.하이토크 클리너 헤드를 장착하면카페트나 마루바닥 등 바닥면을 스스로 감지해서흡입력을 조절해주고, 그에 알맞는 배터리 전여시간을 LCD창을 통해 알려준답니다.한번씩 패브릭의 결 따라서 쭉
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import re
import requests

browser="C:\\Users\CPB06GameN\Anaconda3\envs\chromedriver.exe"
driver=webdriver.Chrome(browser)

url = 'https://blog.naver.com/daily__y/221640619251'
url2 = 'https://blog.naver.com/gmdshop/221636476527'

driver.get(url2)
driver.switch_to.frame('mainFrame')
# html = driver.page_source

# req = requests.get(url)
# html = req.text
soup = BeautifulSoup(html,'html.parser')
driver.find_element_by_css_selector('#div.se-component-content > div > div.blog2_container > span.se_publishDate.pcol2')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-72-b7f705d76804> in <module>
#      18 # html = req.text
#      19 soup = BeautifulSoup(html,'html.parser')
# ---> 20 driver.find_element_by_css_selector('#div.se-component-content > div > div.blog2_container > span.se_publishDate.pcol2')
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# ...
